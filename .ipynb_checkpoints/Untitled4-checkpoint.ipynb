# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DELL

# %%
def compute_flow(img1_path, img2_path):
    img1_path = r"C:\Users\DELL\facial-expressions\data\sample\face1.png"
    img2_path = r"C:\Users\DELL\facial-expressions\data\sample\face2.jpeg"

compute_flow(img1_path, img2_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2     img1_path = r"C:\Users\DELL\facial-expressions\data\sample\face1.png"
#       3     img2_path = r"C:\Users\DELL\facial-expressions\data\sample\face2.jpeg"
# ----> 5 compute_flow(img1_path, img2_path)
#
# NameError: name 'img1_path' is not defined
